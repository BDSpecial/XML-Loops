# %%
import xml.dom.minidom
import xml.etree.ElementTree as ET
from xml.dom.minidom import Node
import pandas as pd

# %%
Historical_DOU_NCH = pd.read_csv("2020 DOU Inpatient NCH.csv")
Q1 = Historical_DOU_NCH[Historical_DOU_NCH.Month.isin([1,2,3])]
Q2 = Historical_DOU_NCH[Historical_DOU_NCH.Month.isin([4,5,6])]
Q3 = Historical_DOU_NCH[Historical_DOU_NCH.Month.isin([7,8,9])]
Q4 = Historical_DOU_NCH[Historical_DOU_NCH.Month.isin([10,11,12])]

# %%
NCH_Data = pd.read_csv("2021_Q2 Inpatient NCH.csv")

# %%
set(NCH_Data.Hospital)
# Out:
# {'EDH', 'EHH', 'EJCH', 'ELTAC', 'ESJH', 'EUH', 'EUHM', 'EUOSH'}

# %%
NCH_Data
# Out:
#     Hospital                                UnitName  Month  RNHospEmplHours  \
# 0        EHH                                  EHH ED      4          5059.14
# 1       EJCH                                   JC ED      6          4232.16
# 2       ESJH                 ESJH Emergency Services      4          6617.17
# 3        EHH                                  EHH ED      6          5228.29
# 4       EJCH                                   JC ED      4          4191.29
# ..       ...                                     ...    ...              ...
# 322     ESJH  3 South Telemetry (Digestive Diseases)      6          3458.75
# 323      EUH                                8T N Onc      5          3334.41
# 324     ESJH                5 West Internal Medicine      5          1918.61
# 325    EUOSH                                OSH PACU      5          1969.80
# 326      EDH                                  EDH 22      5          1625.31
#
#      RNContractEmplHours  LPNHospEmplHours  LPNContractEmplHours  \
# 0                1635.75           2006.86                     0
# 1                1229.57              1.65                     0
# 2                1313.12              0.00                     0
# 3                1392.78           1766.36                     0
# 4                1011.02              3.79                     0
# ..                   ...               ...                   ...
# 322               595.07              0.00                     0
# 323               665.63              0.00                     0
# 324              1431.09              0.00                     0
# 325                25.68              0.00                     0
# 326                63.07              0.00                     0
#
#      UAPHospEmplHours  UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  \
# 0             1724.18                  0.00       1554.48                 0.0
# 1             1050.97                 49.53        305.50                 0.0
# 2              260.88                582.96       1083.76                 0.0
# 3             1516.78                  0.00       1524.11                 0.0
# 4              834.94                  2.57        168.89                 0.0
# ..                ...                   ...           ...                 ...
# 322           1138.42                 82.64           NaN                 NaN
# 323           1224.81                 74.92           NaN                 NaN
# 324           1230.74                 61.10           NaN                 NaN
# 325            149.96                  0.00           NaN                 NaN
# 326            719.07                  0.00           NaN                 NaN
#
#      MHTHospEmplHours  MHTContractEmplHours
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4                 NaN                   NaN
# ..                ...                   ...
# 322               NaN                   NaN
# 323               NaN                   NaN
# 324               NaN                   NaN
# 325               NaN                   NaN
# 326               NaN                   NaN
#
# [327 rows x 13 columns]

# %%
# The variables needed for this function are the: Hospital abbreviation, Hospital NDNQI template, Hospital NDNQI
# code, Calendar year being submitted, and Calendar quarter being submitted
def NDNQI_NCH_XML(Selected_Hosp,Hosp_XML_Template,Hosp_NDNQI_Code,Calendar_Year,Calendar_Quarter):
    # This section is to update the Nursing Care Hours

    # The first step takes only the data for this selected hospital
    Hosp_data = NCH_Data[NCH_Data.Hospital == Selected_Hosp]
    # A List of this Hospital's Unit Names
    Hosp_Units = list(set(Hosp_data.UnitName))
    
    NCH_columns = ['RNHospEmplHours', 'RNContractEmplHours', 'LPNHospEmplHours', 'LPNContractEmplHours', 'UAPHospEmplHours', 'UAPContractEmplHours',
            'ParamedicEmplHours', 'EMTEmplHours']

    #This is the current XML template for this hospital and their NDNQI units for this metric
    tree = xml.dom.minidom.parse(Hosp_XML_Template)
    # This is each unit node of the xml file
    unit_nodes = tree.getElementsByTagName("UnitYrQtr")

    # Make sure the correct NDNQI code, year, and quarter are listed
    H = tree.getElementsByTagName("HospitalCode")[0].childNodes[0].nodeValue = Hosp_NDNQI_Code
    Y = tree.getElementsByTagName("Year")[0].childNodes[0].nodeValue = Calendar_Year
    Q = tree.getElementsByTagName("Quarter")[0].childNodes[0].nodeValue = Calendar_Quarter


    # This loops through each separate UnitName from the Template XML file and replaces it WITH the correct NDNQI name for the units.  
    for idx, unit in enumerate(unit_nodes):
        unit.getElementsByTagName('UnitName')[0].childNodes[0].nodeValue = Hosp_Units[idx]

        # Now grab each of the 3 months for that unit from the Hospital data
        new_data = Hosp_data[Hosp_data.UnitName == Hosp_Units[idx]]
        # Sort the data by month
        new_data = new_data.sort_values('Month')

        # Take each xml Month and replace it with each listed month from the new_data for that unit
        month_nodes = unit.getElementsByTagName("UnitMonth")
        for idx2, month in enumerate(month_nodes):
            month.getElementsByTagName('Month')[0].childNodes[0].nodeValue = new_data.Month.iloc[idx2]
            
            for data in NCH_columns:
                if data in ['ParamedicEmplHours', 'EMTEmplHours'] and pd.isna(new_data[data].iloc[idx2]):
                    month.getElementsByTagName(data)[0].childNodes[0].nodeValue = ""
                    month.getElementsByTagName(data)[0].setAttribute('xsi:nil', 'true')
                else:
                    new_value = new_data[data].iloc[idx2]
                    month.getElementsByTagName(data)[0].childNodes[0].nodeValue = new_value



    # Now, we need to write and save this XML file as its own NDNQI Quarter and Year and Hospital to upload
    # into NDNQI.
    tree.writexml(open('Q{}_{} {} Inpatient NCH.xml'.format(Calendar_Quarter,Calendar_Year,Selected_Hosp), 'w'))

# %% [markdown]
# ## EUOSH

# %%
NDNQI_NCH_XML('EUOSH',"2020 EUOSH NCH Template.xml",'SBI556',2021,2)

# %%
EUOSH_data = NCH_Data[NCH_Data.Hospital == 'EUOSH']
# A List of this Hospital's Unit Names
EUOSH_Units = list(set(EUOSH_data.UnitName))

# %%
EUOSH_data
# Out:
#     Hospital      UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 28     EUOSH       OSH ICU      6           905.75               576.97
# 44     EUOSH          OSH2      5          1596.42                 2.55
# 68     EUOSH       OSH ICU      4           921.58               482.27
# 72     EUOSH   OSH4 / OSH3      4          2846.78               113.68
# 75     EUOSH  OSH POHA/PAT      4           568.32                 0.00
# 113    EUOSH       OSH ICU      5           970.59               658.91
# 121    EUOSH          OSH2      4          2042.76                59.91
# 126    EUOSH      OSH PACU      4          1818.04                19.95
# 190    EUOSH          OSH2      6          1581.18                30.54
# 272    EUOSH   OSH4 / OSH3      5          3041.69               153.14
# 285    EUOSH      OSH PACU      6          1889.72                14.07
# 290    EUOSH   OSH4 / OSH3      6          3039.83               310.68
# 296    EUOSH  OSH POHA/PAT      6           512.14                16.11
# 308    EUOSH  OSH POHA/PAT      5           543.30                 1.14
# 325    EUOSH      OSH PACU      5          1969.80                25.68
#
#      LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 28                0.0                     0              0.00
# 44                0.0                     0            472.59
# 68                0.0                     0             22.75
# 72                0.0                     0            719.69
# 75                0.0                     0            144.82
# 113               0.0                     0             13.75
# 121               0.0                     0            660.94
# 126               0.0                     0            103.00
# 190               0.0                     0            429.89
# 272               0.0                     0            745.66
# 285               0.0                     0              0.00
# 290               0.0                     0            802.28
# 296               0.0                     0            159.86
# 308               0.0                     0            159.11
# 325               0.0                     0            149.96
#
#      UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 28                   0.00           NaN                 NaN               NaN
# 44                   0.00           NaN                 NaN               NaN
# 68                   0.00           NaN                 NaN               NaN
# 72                  12.00           NaN                 NaN               NaN
# 75                   0.00           NaN                 NaN               NaN
# 113                  0.00           NaN                 NaN               NaN
# 121                  0.00           NaN                 NaN               NaN
# 126                  0.00           NaN                 NaN               NaN
# 190                  0.00           NaN                 NaN               NaN
# 272                 13.71           NaN                 NaN               NaN
# 285                 65.64           NaN                 NaN               NaN
# 290                 12.93           NaN                 NaN               NaN
# 296                  0.00           NaN                 NaN               NaN
# 308                  0.00           NaN                 NaN               NaN
# 325                  0.00           NaN                 NaN               NaN
#
#      MHTContractEmplHours
# 28                    NaN
# 44                    NaN
# 68                    NaN
# 72                    NaN
# 75                    NaN
# 113                   NaN
# 121                   NaN
# 126                   NaN
# 190                   NaN
# 272                   NaN
# 285                   NaN
# 290                   NaN
# 296                   NaN
# 308                   NaN
# 325                   NaN

# %% [markdown]
# ## EJCH

# %%
NDNQI_NCH_XML('EJCH','2020 EJCH NCH Template.xml','YTD069',2021,2)

# %%
EJCH_data = NCH_Data[NCH_Data.Hospital == 'EJCH']
# A List of this Hospital's Unit Names
EJCH_Units = list(set(EJCH_data.UnitName))

# %%
EJCH_data
# Out:
#     Hospital         UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 1       EJCH            JC ED      6          4232.16              1229.57
# 4       EJCH            JC ED      4          4191.29              1011.02
# 12      EJCH            JC ED      5          4452.43              1216.09
# 26      EJCH           JC ICU      6          5009.89               404.39
# 48      EJCH           JC ICU      5          5397.46               321.13
# 50      EJCH              JC4      4          5612.14               567.89
# 53      EJCH  JC Neonatal ICU      6          2746.57                 0.00
# 54      EJCH          JC PACU      5          1483.34                 0.00
# 64      EJCH  JC Neonatal ICU      4          3265.64                 0.00
# 70      EJCH              JC3      6          5922.32               647.83
# 104     EJCH            JC MB      6          2170.43                 0.00
# 131     EJCH           JC ICU      4          5646.22               291.86
# 150     EJCH          JC PACU      6          1389.86                 0.00
# 155     EJCH      JC Oncology      5          2428.19                41.42
# 169     EJCH              JC3      5          6432.41               443.87
# 170     EJCH  JC Neonatal ICU      5          2900.70                 0.00
# 179     EJCH          JC PACU      4          1346.57                24.73
# 180     EJCH              JC3      4          6336.38               695.57
# 209     EJCH      JC Oncology      6          2448.02                77.58
# 214     EJCH           JC SDS      6          3213.65                 0.00
# 225     EJCH              JC4      6          5106.84               601.35
# 251     EJCH            JC MB      4          2093.97                 0.00
# 253     EJCH           JC SDS      4          3131.22                 0.00
# 256     EJCH      JC Oncology      4          2281.97                54.15
# 269     EJCH           JC SDS      5          3453.92                 0.00
# 276     EJCH            JC MB      5          2154.25                 0.00
# 317     EJCH              JC4      5          5776.23               693.04
#
#      LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 1                1.65                     0           1050.97
# 4                3.79                     0            834.94
# 12               6.48                     0            838.04
# 26               0.00                     0            417.89
# 48               0.00                     0            395.75
# 50             676.32                     0           2665.96
# 53               0.00                     0              0.00
# 54               0.00                     0              0.48
# 64               0.00                     0              0.00
# 70             281.50                     0           2424.60
# 104              0.00                     0            291.43
# 131              0.00                     0            511.56
# 150              0.00                     0              0.00
# 155              0.00                     0           1033.16
# 169            344.32                     0           2590.13
# 170              0.00                     0              0.00
# 179              0.00                     0              6.27
# 180            332.65                     0           2348.77
# 209              0.00                     0            975.68
# 214              0.00                     0              0.00
# 225            430.29                     0           2586.00
# 251              0.00                     0            152.13
# 253              0.00                     0              0.00
# 256              0.00                     0            997.11
# 269              0.00                     0              0.00
# 276              0.00                     0            228.89
# 317            523.93                     0           2622.31
#
#      UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 1                   49.53        305.50                 0.0               NaN
# 4                    2.57        168.89                 0.0               NaN
# 12                  26.43        291.43                 0.0               NaN
# 26                   3.36           NaN                 NaN               NaN
# 48                  14.29           NaN                 NaN               NaN
# 50                   2.57           NaN                 NaN               NaN
# 53                   0.00           NaN                 NaN               NaN
# 54                   0.00           NaN                 NaN               NaN
# 64                   0.00           NaN                 NaN               NaN
# 70                  80.79           NaN                 NaN               NaN
# 104                 12.25           NaN                 NaN               NaN
# 131                 61.60           NaN                 NaN               NaN
# 150                  0.00           NaN                 NaN               NaN
# 155                  1.71           NaN                 NaN               NaN
# 169                153.07           NaN                 NaN               NaN
# 170                  0.00           NaN                 NaN               NaN
# 179                  0.00           NaN                 NaN               NaN
# 180                232.68           NaN                 NaN               NaN
# 209                 10.29           NaN                 NaN               NaN
# 214                  0.00           NaN                 NaN               NaN
# 225                 20.57           NaN                 NaN               NaN
# 251                  0.00           NaN                 NaN               NaN
# 253                  0.00           NaN                 NaN               NaN
# 256                  2.57           NaN                 NaN               NaN
# 269                  0.00           NaN                 NaN               NaN
# 276                 12.00           NaN                 NaN               NaN
# 317                 15.43           NaN                 NaN               NaN
#
#      MHTContractEmplHours
# 1                     NaN
# 4                     NaN
# 12                    NaN
# 26                    NaN
# 48                    NaN
# 50                    NaN
# 53                    NaN
# 54                    NaN
# 64                    NaN
# 70                    NaN
# 104                   NaN
# 131                   NaN
# 150                   NaN
# 155                   NaN
# 169                   NaN
# 170                   NaN
# 179                   NaN
# 180                   NaN
# 209                   NaN
# 214                   NaN
# 225                   NaN
# 251                   NaN
# 253                   NaN
# 256                   NaN
# 269                   NaN
# 276                   NaN
# 317                   NaN

# %% [markdown]
# ## ESJH

# %%
NDNQI_NCH_XML('ESJH','2020 ESJH NCH Template.xml','XAR317',2021,2)

# %%
ESJH_data = NCH_Data[NCH_Data.Hospital == 'ESJH']
# A List of this Hospital's Unit Names
ESJH_Units = list(set(ESJH_data.UnitName))

# %%
ESJH_data
# Out:
#     Hospital                                           UnitName  Month  \
# 2       ESJH                            ESJH Emergency Services      4
# 7       ESJH                            ESJH Emergency Services      6
# 9       ESJH                            ESJH Emergency Services      5
# 24      ESJH                   4 East Telemetry (Neurovascular)      6
# 29      ESJH                       ESJH 7 West Complex Med-Surg      4
# 45      ESJH  ESJH Pre-Postoperative (PAT, Pre-Op, PSCU, Gro...      4
# 47      ESJH                   3 East Telemetry (CV Step- down)      4
# 52      ESJH                                     3 Southwest GI      4
# 62      ESJH                   4 West Telemetry (Renal-Urology)      4
# 66      ESJH                       ESJH 7 West Complex Med-Surg      6
# 73      ESJH                               ESJH 7 East Oncology      6
# 78      ESJH                     4 South Telemetry (Orthopedic)      4
# 82      ESJH                                         2 East ICU      6
# 83      ESJH                                         2 East ICU      5
# 85      ESJH                       ESJH 7 West Complex Med-Surg      5
# 90      ESJH              6 West Telemetry (Pulmonary-thoracic)      5
# 94      ESJH               6 East Telemetry (Internal medicine)      4
# 101     ESJH                               2 South CV Step-down      5
# 103     ESJH                               2 South CV Step-down      6
# 105     ESJH                                     3 Southwest GI      6
# 108     ESJH             3 South Telemetry (Digestive Diseases)      4
# 112     ESJH              6 West Telemetry (Pulmonary-thoracic)      4
# 129     ESJH                                         2 West ICU      5
# 138     ESJH                     4 South Telemetry (Orthopedic)      5
# 148     ESJH                                    2 Southwest ICU      4
# 156     ESJH  ESJH Pre-Postoperative (PAT, Pre-Op, PSCU, Gro...      6
# 158     ESJH               6 East Telemetry (Internal medicine)      6
# 159     ESJH                   4 East Telemetry (Neurovascular)      5
# 164     ESJH                   4 East Telemetry (Neurovascular)      4
# 176     ESJH                                    2 Southwest ICU      6
# 197     ESJH                           5 East Internal Medicine      6
# 204     ESJH                                     3 Southwest GI      5
# 211     ESJH              6 West Telemetry (Pulmonary-thoracic)      6
# 217     ESJH                                  3 West Cardiology      5
# 219     ESJH                                         2 West ICU      4
# 223     ESJH                                  3 West Cardiology      6
# 240     ESJH             3 South Telemetry (Digestive Diseases)      5
# 248     ESJH                   4 West Telemetry (Renal-Urology)      5
# 259     ESJH                               ESJH 7 East Oncology      4
# 260     ESJH                   4 West Telemetry (Renal-Urology)      6
# 270     ESJH               6 East Telemetry (Internal medicine)      5
# 274     ESJH                                         2 East ICU      4
# 275     ESJH                   3 East Telemetry (CV Step- down)      5
# 281     ESJH                                  3 West Cardiology      4
# 286     ESJH                                         2 West ICU      6
# 287     ESJH                               ESJH 7 East Oncology      5
# 294     ESJH                           5 West Internal Medicine      6
# 295     ESJH  ESJH Pre-Postoperative (PAT, Pre-Op, PSCU, Gro...      5
# 300     ESJH                           5 East Internal Medicine      5
# 301     ESJH                                    2 Southwest ICU      5
# 303     ESJH                     4 South Telemetry (Orthopedic)      6
# 310     ESJH                   3 East Telemetry (CV Step- down)      6
# 311     ESJH                           5 East Internal Medicine      4
# 313     ESJH                           5 West Internal Medicine      4
# 319     ESJH                               2 South CV Step-down      4
# 322     ESJH             3 South Telemetry (Digestive Diseases)      6
# 324     ESJH                           5 West Internal Medicine      5
#
#      RNHospEmplHours  RNContractEmplHours  LPNHospEmplHours  \
# 2            6617.17              1313.12               0.0
# 7            6739.04              1752.53               0.0
# 9            7102.04              1686.27               0.0
# 24           3824.11               118.90               0.0
# 29           3140.05               408.34               0.0
# 45           5439.30               659.79               0.0
# 47           3836.93               385.85               0.0
# 52           2776.06               439.77               0.0
# 62           3365.97               352.32               0.0
# 66           3246.82               523.61               0.0
# 73           3552.36               501.64               0.0
# 78           4240.16               173.28               0.0
# 82           4648.71              2217.42               0.0
# 83           4564.02              1911.25               0.0
# 85           3319.36               874.52               0.0
# 90           3142.98              1125.23               0.0
# 94           3115.84              1120.21               0.0
# 101          3298.04              2428.35               0.0
# 103          2840.46              1652.90               0.0
# 105          2569.68               486.65               0.0
# 108          3129.27               571.82               0.0
# 112          2892.39              1506.15               0.0
# 129          5746.72              1764.54               0.0
# 138          4920.30               152.79               0.0
# 148          7170.55              1230.00               0.0
# 156          5335.33              1043.86               0.0
# 158          2713.89              1409.29               0.0
# 159          3950.20                90.78               0.0
# 164          3818.66                88.57               0.0
# 176          7040.75              1163.18               0.0
# 197          2289.70              2713.72               0.0
# 204          2776.25               739.87               0.0
# 211          2865.32              1349.64               0.0
# 217          2822.30               286.75               0.0
# 219          5301.35              1485.46               0.0
# 223          3144.74               386.82               0.0
# 240          3335.62               904.63               0.0
# 248          3325.68               864.32               0.0
# 259          3154.46               617.52               0.0
# 260          3652.96               530.11               0.0
# 270          2926.59              1260.18               0.0
# 274          4060.56              1406.11               0.0
# 275          3761.84               464.27               0.0
# 281          2861.60               242.23               0.0
# 286          5121.37              1583.53               0.0
# 287          3444.34               850.34               0.0
# 294          2692.18              2344.22               0.0
# 295          5567.73              1407.27               0.0
# 300          2133.90              2443.16               0.0
# 301          7696.74              1861.20               0.0
# 303          4210.40                38.61               0.0
# 310          3641.86               257.25               0.0
# 311          1885.51              2043.93               0.0
# 313          1814.72              1287.60               0.0
# 319          3385.56              1806.16               0.0
# 322          3458.75               595.07               0.0
# 324          1918.61              1431.09               0.0
#
#      LPNContractEmplHours  UAPHospEmplHours  UAPContractEmplHours  \
# 2                       0            260.88                582.96
# 7                       0            283.71                801.58
# 9                       0            266.57                862.07
# 24                      0           1250.22                 45.25
# 29                      0            954.94                323.08
# 45                      0           1162.75                  0.00
# 47                      0           1180.41                 64.84
# 52                      0           1096.04                 59.07
# 62                      0           1206.98                109.86
# 66                      0           1067.32                177.22
# 73                      0            669.25                409.39
# 78                      0           1398.93                157.27
# 82                      0            290.48                 22.11
# 83                      0            339.22                 13.64
# 85                      0           1068.65                104.77
# 90                      0           1328.06                 74.20
# 94                      0           1313.52                 58.73
# 101                     0            777.30                190.00
# 103                     0           1154.75                143.32
# 105                     0            995.11                113.00
# 108                     0           1176.50                 78.23
# 112                     0           1243.41                101.95
# 129                     0            141.43                 36.25
# 138                     0           1547.02                129.26
# 148                     0            500.59                  0.00
# 156                     0           1362.43                  0.00
# 158                     0            954.29                144.18
# 159                     0           1332.35                 74.86
# 164                     0           1392.90                 25.53
# 176                     0            576.91                 12.00
# 197                     0           1108.54                193.36
# 204                     0           1122.46                 63.22
# 211                     0           1152.93                142.32
# 217                     0           1253.39                127.61
# 219                     0            281.59                  8.00
# 223                     0           1152.22                112.75
# 240                     0           1359.22                130.97
# 248                     0           1375.39                 36.09
# 259                     0            955.97                198.93
# 260                     0           1040.22                140.86
# 270                     0           1210.02                 90.96
# 274                     0            334.29                  0.00
# 275                     0           1321.37                143.16
# 281                     0           1187.00                140.58
# 286                     0            148.25                  8.00
# 287                     0            792.32                336.63
# 294                     0           1092.82                114.54
# 295                     0           1523.04                  0.00
# 300                     0           1166.80                 88.11
# 301                     0            643.35                  0.00
# 303                     0           1245.96                 99.04
# 310                     0           1105.22                 93.29
# 311                     0           1078.75                173.02
# 313                     0            962.22                134.29
# 319                     0            987.88                148.71
# 322                     0           1138.42                 82.64
# 324                     0           1230.74                 61.10
#
#      EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  MHTContractEmplHours
# 2         1083.76                 0.0               NaN                   NaN
# 7         1055.75                 0.0               NaN                   NaN
# 9         1134.95                 0.0               NaN                   NaN
# 24            NaN                 NaN               NaN                   NaN
# 29            NaN                 NaN               NaN                   NaN
# 45            NaN                 NaN               NaN                   NaN
# 47            NaN                 NaN               NaN                   NaN
# 52            NaN                 NaN               NaN                   NaN
# 62            NaN                 NaN               NaN                   NaN
# 66            NaN                 NaN               NaN                   NaN
# 73            NaN                 NaN               NaN                   NaN
# 78            NaN                 NaN               NaN                   NaN
# 82            NaN                 NaN               NaN                   NaN
# 83            NaN                 NaN               NaN                   NaN
# 85            NaN                 NaN               NaN                   NaN
# 90            NaN                 NaN               NaN                   NaN
# 94            NaN                 NaN               NaN                   NaN
# 101           NaN                 NaN               NaN                   NaN
# 103           NaN                 NaN               NaN                   NaN
# 105           NaN                 NaN               NaN                   NaN
# 108           NaN                 NaN               NaN                   NaN
# 112           NaN                 NaN               NaN                   NaN
# 129           NaN                 NaN               NaN                   NaN
# 138           NaN                 NaN               NaN                   NaN
# 148           NaN                 NaN               NaN                   NaN
# 156           NaN                 NaN               NaN                   NaN
# 158           NaN                 NaN               NaN                   NaN
# 159           NaN                 NaN               NaN                   NaN
# 164           NaN                 NaN               NaN                   NaN
# 176           NaN                 NaN               NaN                   NaN
# 197           NaN                 NaN               NaN                   NaN
# 204           NaN                 NaN               NaN                   NaN
# 211           NaN                 NaN               NaN                   NaN
# 217           NaN                 NaN               NaN                   NaN
# 219           NaN                 NaN               NaN                   NaN
# 223           NaN                 NaN               NaN                   NaN
# 240           NaN                 NaN               NaN                   NaN
# 248           NaN                 NaN               NaN                   NaN
# 259           NaN                 NaN               NaN                   NaN
# 260           NaN                 NaN               NaN                   NaN
# 270           NaN                 NaN               NaN                   NaN
# 274           NaN                 NaN               NaN                   NaN
# 275           NaN                 NaN               NaN                   NaN
# 281           NaN                 NaN               NaN                   NaN
# 286           NaN                 NaN               NaN                   NaN
# 287           NaN                 NaN               NaN                   NaN
# 294           NaN                 NaN               NaN                   NaN
# 295           NaN                 NaN               NaN                   NaN
# 300           NaN                 NaN               NaN                   NaN
# 301           NaN                 NaN               NaN                   NaN
# 303           NaN                 NaN               NaN                   NaN
# 310           NaN                 NaN               NaN                   NaN
# 311           NaN                 NaN               NaN                   NaN
# 313           NaN                 NaN               NaN                   NaN
# 319           NaN                 NaN               NaN                   NaN
# 322           NaN                 NaN               NaN                   NaN
# 324           NaN                 NaN               NaN                   NaN

# %% [markdown]
# ## EUH

# %%
NDNQI_NCH_XML('EUH','2020 EUH NCH Template.xml','JXE432',2021,2)

# %%
EUH_data = NCH_Data[NCH_Data.Hospital == 'EUH']
# A List of this Hospital's Unit Names
EUH_Units = list(set(EUH_data.UnitName))

# %%
EUH_data
# Out:
#     Hospital           UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 8        EUH             EUH ED      6          8982.39              1225.29
# 10       EUH             EUH ED      5         10454.70               219.59
# 15       EUH             EUH ED      4         10338.41                99.50
# 22       EUH         5G Medical      6          1771.88              1135.52
# 27       EUH         6B Rollins      5           652.70               187.10
# ..       ...                ...    ...              ...                  ...
# 304      EUH  WW Inpatient Unit      5          4161.34                 1.45
# 305      EUH          2D/2G ICU      4         16695.20               133.29
# 306      EUH    8T S Hematology      4          6302.70               237.56
# 316      EUH              6E CV      6          4705.35               640.44
# 323      EUH           8T N Onc      5          3334.41               665.63
#
#      LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 8                 0.0                     0           1633.82
# 10                0.0                     0           1425.00
# 15                0.0                     0           1514.29
# 22                0.0                     0           1392.68
# 27                0.0                     0            404.07
# ..                ...                   ...               ...
# 304               0.0                     0           1174.09
# 305               0.0                     0           1075.91
# 306               0.0                     0           2070.82
# 316               0.0                     0           1960.11
# 323               0.0                     0           1224.81
#
#      UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 8                  444.32       1083.18                 0.0               NaN
# 10                 350.34       1167.29                 0.0               NaN
# 15                 178.45       1221.25                 0.0               NaN
# 22                  89.92           NaN                 NaN               NaN
# 27                 221.25           NaN                 NaN               NaN
# ..                    ...           ...                 ...               ...
# 304                 75.50           NaN                 NaN               NaN
# 305                  0.00           NaN                 NaN               NaN
# 306                 31.38           NaN                 NaN               NaN
# 316                 70.72           NaN                 NaN               NaN
# 323                 74.92           NaN                 NaN               NaN
#
#      MHTContractEmplHours
# 8                     NaN
# 10                    NaN
# 15                    NaN
# 22                    NaN
# 27                    NaN
# ..                    ...
# 304                   NaN
# 305                   NaN
# 306                   NaN
# 316                   NaN
# 323                   NaN
#
# [84 rows x 13 columns]

# %% [markdown]
# ## EUHM

# %%
NDNQI_NCH_XML('EUHM','2020 EUHM NCH Template.xml','PVF155',2021,2)

# %%
EUHM_data = NCH_Data[NCH_Data.Hospital == 'EUHM']
# A List of this Hospital's Unit Names
EUHM_Units = list(set(EUHM_data.UnitName))

# %%
EUHM_data
# Out:
#     Hospital            UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 11      EUHM             EUHM ED      4          6712.63              3461.07
# 13      EUHM             EUHM ED      5          8045.67              3401.77
# 17      EUHM             EUHM ED      6          7757.25              5305.18
# 21      EUHM           U62 Renal      4          2610.37              1451.33
# 23      EUHM     72 Stroke/Neuro      4          2140.29               798.21
# ..       ...                 ...    ...              ...                  ...
# 288     EUHM              71 ICU      4          6153.16               778.11
# 293     EUHM              71 ICU      6          5719.82              1146.21
# 299     EUHM  U61 Med (COVID-19)      4          5086.65              2203.73
# 307     EUHM              11 ICU      5          3131.48              1419.87
# 321     EUHM              11 ICU      4          3241.77              1340.79
#
#      LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 11                0.0                     0           3637.50
# 13                0.0                     0           3920.24
# 17                0.0                     0           3556.43
# 21                0.0                     0           1002.57
# 23                0.0                     0           1497.57
# ..                ...                   ...               ...
# 288               0.0                     0            778.87
# 293               0.0                     0            666.50
# 299               0.0                     0           3313.96
# 307               0.0                     0            592.75
# 321               0.0                     0            624.00
#
#      UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 11                   0.00        551.61                 0.0               NaN
# 13                  23.50        741.59                 0.0               NaN
# 17                  15.18        566.43                 0.0               NaN
# 21                 314.95           NaN                 NaN               NaN
# 23                  48.54           NaN                 NaN               NaN
# ..                    ...           ...                 ...               ...
# 288                  2.57           NaN                 NaN               NaN
# 293                 14.11           NaN                 NaN               NaN
# 299                 63.63           NaN                 NaN               NaN
# 307                  0.79           NaN                 NaN               NaN
# 321                 10.21           NaN                 NaN               NaN
#
#      MHTContractEmplHours
# 11                    NaN
# 13                    NaN
# 17                    NaN
# 21                    NaN
# 23                    NaN
# ..                    ...
# 288                   NaN
# 293                   NaN
# 299                   NaN
# 307                   NaN
# 321                   NaN
#
# [66 rows x 13 columns]

# %% [markdown]
# ## EDH

# %%
NDNQI_NCH_XML('EDH','2021 EDH NCH Template.xml','NMW346',2021,2)

# %%
EDH_data = NCH_Data[NCH_Data.Hospital == 'EDH']
# A List of this Hospital's Unit Names
EDH_Units = list(set(EDH_data.UnitName))

# %%
EDH_data.head()
# Out:
#    Hospital UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 5       EDH   EDH ED      5          6050.00              1768.25
# 6       EDH   EDH ED      6          5954.49              1733.29
# 14      EDH   EDH ED      4          5396.61              3120.23
# 18      EDH   EDH 18      4          1539.50                57.75
# 19      EDH   EDH 18      6          1711.47                54.00
#
#     LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 5            1503.43                     0            665.02
# 6            1456.93                     0           1065.72
# 14           1429.18                     0            513.34
# 18              0.00                     0             62.07
# 19              0.00                     0             51.50
#
#     UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 5                  64.84       2448.93                 0.0               NaN
# 6                  31.86       2354.21                 0.0               NaN
# 14                 31.68       2430.50                 0.0               NaN
# 18                 63.57           NaN                 NaN           2225.23
# 19                143.15           NaN                 NaN           2487.07
#
#     MHTContractEmplHours
# 5                    NaN
# 6                    NaN
# 14                   NaN
# 18                   0.0
# 19                   0.0

# %% [markdown]
# ## EHH

# %%
NDNQI_NCH_XML('EHH','2021 EHH NCH Template.xml','WXX116',2021,2)

# %%
EHH_data = NCH_Data[NCH_Data.Hospital == 'EHH']
# A List of this Hospital's Unit Names
EHH_Units = list(set(EHH_data.UnitName))

# %%
EHH_data.head()
# Out:
#    Hospital   UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 0       EHH     EHH ED      4          5059.14              1635.75
# 3       EHH     EHH ED      6          5228.29              1392.78
# 16      EHH     EHH ED      5          4987.07              1374.52
# 41      EHH  EHH 4 ICU      6            61.32               199.15
# 57      EHH  EHH 4 ICU      4           437.62               831.79
#
#     LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 0            2006.86                     0           1724.18
# 3            1766.36                     0           1516.78
# 16           1892.67                     0           1624.79
# 41              0.00                     0             10.29
# 57              0.00                     0            163.82
#
#     UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 0                    0.0       1554.48                 0.0               NaN
# 3                    0.0       1524.11                 0.0               NaN
# 16                   0.0       1661.75                 0.0               NaN
# 41                   0.0           NaN                 NaN               NaN
# 57                   0.0           NaN                 NaN               NaN
#
#     MHTContractEmplHours
# 0                    NaN
# 3                    NaN
# 16                   NaN
# 41                   NaN
# 57                   NaN

# %% [markdown]
# ## ELTAC

# %%
NDNQI_NCH_XML('ELTAC','2021 ELTAC NCH Template.xml','XLS464',2021,2)

# %%
ELTAC_data = NCH_Data[NCH_Data.Hospital == 'ELTAC']
# A List of this Hospital's Unit Names
ELTAC_Units = list(set(ELTAC_data.UnitName))

# %%
ELTAC_data
# Out:
#     Hospital     UnitName  Month  RNHospEmplHours  RNContractEmplHours  \
# 51     ELTAC    ELTAC 4/5      5          3315.97              3664.24
# 67     ELTAC    ELTAC 4/5      4          3603.68              3013.67
# 134    ELTAC    ELTAC 4/5      6          3095.46              3188.14
# 167    ELTAC  ELTAC 5 ICU      4          1036.87                 5.09
# 213    ELTAC  ELTAC 5 ICU      5           866.59                14.21
# 226    ELTAC  ELTAC 5 ICU      6           988.54                10.29
#
#      LPNHospEmplHours  LPNContractEmplHours  UAPHospEmplHours  \
# 51                0.0                     0           4646.25
# 67                0.0                     0           3944.86
# 134               0.0                     0           3866.82
# 167               0.0                     0            344.42
# 213               0.0                     0              7.79
# 226               0.0                     0            209.71
#
#      UAPContractEmplHours  EMTEmplHours  ParamedicEmplHours  MHTHospEmplHours  \
# 51                   2.25           NaN                 NaN               NaN
# 67                   0.00           NaN                 NaN               NaN
# 134                 18.00           NaN                 NaN               NaN
# 167                  0.00           NaN                 NaN               NaN
# 213                  0.00           NaN                 NaN               NaN
# 226                  0.00           NaN                 NaN               NaN
#
#      MHTContractEmplHours
# 51                    NaN
# 67                    NaN
# 134                   NaN
# 167                   NaN
# 213                   NaN
# 226                   NaN
